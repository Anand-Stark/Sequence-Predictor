# %%
x = [.415, .63, .756, .809, .846, .873, .90, .935, .954, .952, .955, .958, .964, .9672, .967, .9715, .9826, .9829, .9801, .983]
y = range(1, 21)

# %%
import matplotlib.pyplot as plt

# Creating the line graph
plt.figure(figsize=(10, 5))  # Set the figure size (optional)
plt.plot(y, x)
plt.title('Realm Classification - Model Accuracy over Epochs')  # Title of the graph
plt.xlabel('Epochs')  # X-axis label
plt.ylabel('Accuracy')  # Y-axis label

# Show the graph
plt.show()

# %%
x = [0.98, 1, 1, 1, 1]
y = range(1, 6)

# Creating the line graph
plt.figure(figsize=(10, 5))  # Set the figure size (optional)
plt.plot(y, x)
plt.title('Sars_CoV 2 Classification - Model Accuracy over Epochs')  # Title of the graph
plt.xlabel('Epochs')  # X-axis label
plt.ylabel('Accuracy')  # Y-axis label

# Show the graph
plt.show()

# %%
x = [0.26, 0.458, 0.54, 0.67, 0.71, 0.74, 0.77, 0.82, 0.833, 0.837, 0.844, 0.864, 0.87, 0.84, 0.87, 0.869, 0.864, 0.871, 0.89, 0.89]
y = range(1, 21)

# Creating the line graph
plt.figure(figsize=(10, 5))  # Set the figure size (optional)
plt.plot(y, x)
plt.title('Coronavirus Classification - Model Accuracy over Epochs')  # Title of the graph
plt.xlabel('Epochs')  # X-axis label
plt.ylabel('Accuracy')  # Y-axis label

# Show the graph
plt.show()
